# %% [markdown]
# # Trabajo Práctico 1 - Cálculo de Ranking Page

# %% [markdown]
# ## Enunciado

# %% [markdown]
# ### Pregunta 1 - ¿Por que la matriz A definida en (4) es equivalente a $p \ \mathbf{W} \ \mathbf{D} + e \ z^t$ ? Justificar.

# %% [markdown]
# Respuesta:
#
# Se define en (4) la matriz $A \in \mathbb{R}^{nxn}$ donde
# $$
# a_{ij} = \left\{
# \begin{array}{lr}
# (1-p)/n + pw_{ij}/c_j & : c_j \neq 0 \\
# 1/n & : c_j = 0
# \end{array}
# \right.
# $$
# Donde $ n$ es igual a la cantidad de paginas web. Luego se definen la matriz $ z \in \mathbb{R}^{nx1} $ y la matriz $ D \in \mathbb{R}^{nxn}$, donde
# $$
# z_{j} = \left\{
# \begin{array}{lr}
# (1-p)/n & \text{ si } c_j \neq 0 \\
# 1/n & \text{ si } c_j = 0
# \end{array}
# \right.
# \qquad
# \qquad
# y
# \qquad
# \qquad
# d_{jj} = \left\{
# \begin{array}{lr}
#  1/c_j  & \text{ si } c_j \neq 0 \\
# 0 & \text{ si } c_j = 0
# \end{array}
# \right.
# $$
# Recordemos también que la matriz de conectividad $ W $ fue definida como
# $$
# w_{ij} = \left\{
# \begin{array}{lr}
# 1 & \text { si la pagina j tiene un link a la pagina i} \\
# 0 & \text { si no}
# \end{array}
# \right.
# $$
# Entonces, teniendo en cuenta lo anterior, los elementos de WD serian
# $$
# (WD)_{ij} = \left\{
# \begin{array}{lr}
# w_{ij}/c_j & : c_j \neq 0 \\
# 0& : c_j = 0
# \end{array}
# \right.
# $$
# Por lo tanto:
# $$
# (pWD)_{ij} = \left\{
# \begin{array}{lr}
# pw_{ij}/c_j & : c_j \neq 0 \\
# 0& : c_j = 0
# \end{array}
# \right.
# $$
# Por otro lado, notaemos que la matriz $ z$ es un vector columna, entonces $ z^T\in\mathbb{R}^{1xn} $. Tambien se define $e $, un vector columna de unos de dimensión n. Entcones, el producto $ez^T$ tiene sus elementos definidos como
# $$
# (ez^T)_{ij} = \left\{
# \begin{array}{lr}
# (1-p)/n & : c_j \neq 0 \\
# 1/n& : c_j = 0
# \end{array}
# \right.
# $$
# Podemos concluir que la suma $pWD+ez^T$ es igual a
# $$
# (pWD+ez^T)_{ij} = \left\{
# \begin{array}{lr}
# (1-p)/n + pw_{ij}/c_j & : c_j \neq 0 \\
# 1/n & : c_j = 0
# \end{array}
# \right.
# $$
#
# Por lo tanto, $ A = pWD + ez^T $.

# %% [markdown]
# ### Pregunta 2 -  ¿Cómo se garantiza existencia de la factorización $LU$? ¿ La matriz $(\mathbf{I} - p \ \mathbf{W} \ \mathbf{D})$ está bien condicionada? ¿Cómo influye el valor de $p$?

# %% [markdown]
# Primero demostremos que la matriz $I-pWD$ tiene factorizacion LU. Llamemosla L por comodidad.
#
# Vamos a lograr la demostracion si logramos probar que la matriz $L^T$ es **EDD** (estrictamente diagonal dominante), y sus . Por la proposicion 4.2 del apunte, si $L$ una matriz real o compleja cuadrada EDD, entonces $L$ es inversible. Ademas, si $L$ es inversible, $L^T$ tambien lo es.
#
# Por definicion de EDD, planteamos
# $$
# \forall \; i\; , \: 1 \leqslant i \leqslant n \Rightarrow \ |(L^t)_{ii}| > \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} |(L^t)_{ij}|
# $$
# Sabemos que las diagonales son siempre 1, o sea que es lo mismo decir
# $$
# \forall \; i\;, \: 1 \leqslant i \leqslant n \Rightarrow \ 1 > \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} |(L^t)_{ij}|
# $$
# Siguiendo,
# $$
# \sum_{1 \leqslant j \leqslant n,  j\neq i}^{n} |(H^t)_{ij}| = \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} \left\vert-p\frac{(W^t)_{ij}}{c_i}\right\vert = \sum_{1 \leqslant j \leqslant n,
# j\neq i}^{n} p\frac{(W^t)_{ij}}{c_i}
# $$
#
# pues estos elementos se restan a $0$, quedando el mismo valor pero negativo. Como $p$ debe ser mayor que 0, y $\frac{(W^t)_{ij}}{c_i} \geq 0$, luego
#
# $$ \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} |(H^t)_{ij}| = p \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} \frac{(W^t)_{ij}}{c_i}$$
#
# $     1 \leqslant j \leqslant n,    $
#
# Acotando, como p debe ser menor que 1,
# $$
# p* \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} \frac{(W^t)_{ij}}{c_i} < \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} \frac{(W^t)_{ij}}{c_i} = \frac{1}{c_i}* \sum_{1 \leqslant j \leqslant n, j\neq i}^{n} (W^t)_{ij}
# $$
# O sea que, como solo tomamos $W^T$, vale que
# $$
#  \; \sum_{1 \leqslant j \leqslant n,   j\neq i}^{n} (W^T)_{ij} = c_i \;
# $$
# entonces vale decir
# $$
# \frac{1}{c_i}* \sum_{j=1\wedge j\neq i}^{n} (W^t)_{ij} = \frac{c_i}{c_i} = 1
# $$
#
# Por lo tanto, $L^T$ es
# **EDD**

# %% [markdown]
# Para finalizar y verificar que $L$ tiene factorización LU,
# necesitamos demostrar que si $L^T$ es EDD, entonces todas sus submatrices
# principales también son EDD.
#
# Consideremos una submatriz principal $M$ de $L^T$ de tamaño $k \times k$.
# Por definición, una submatriz principal de $L^T$ se obtiene eliminando las
# mismas filas y columnas de $L^T$. Dado que $L^T$ es EDD, para cualquier $i$
# en $M$,
# $$
# |(M)_{ii}| = |(L^T)_{ii}| > \sum_{1 \leqslant j \leqslant k, j \neq i} |(M)_{ij}|
# $$
# Esto se debe a que eliminar filas y columnas correspondientes no
# aumenta la suma de los elementos no diagonales restantes, y la condición de EDD
# se mantiene.
#
# En resumen, si $L^T$ es EDD, todas sus submatrices principales también son EDD,
# y por lo tanto, invertibles.
#
# Así hemos demostrado que $L^T$ es EDD y todas sus submatrices principales
# también lo son, garantizando que $L$ tiene factorización LU.

# %% [markdown]
# ---

# %% [markdown]
# ## Implementación

# %% [markdown]
# Implementar la factorización $LU$ para resolver el sistema de ecuaciones (6) que permite hallar la solución buscada (es decir, el ranking de páginas). Se podrá utilizar la función **scipy.linalg.solve_triangular** para resolver sistemas triangulares.
#
# En el siguiente cuerpo de la notebook se genera un test que va a evaluar la función que resuelve el sistema a través de un test unitario. La resolución debe realizarse en el archivo **funciones.py** que acompaña el **template-alumnos**.

# %%
from funciones import *

# %% [markdown]
# ### Test Unitario
# En el archivo funciones.py hay que implementar la función que obtienen el ranking de las páginas.
# Se espera que el llamado a la siguiente función arroje un valor esperado

# %%
#ARCHIVOS DE ENTRADA
archivo_test = './tests/test_dosestrellas.txt'
    
#CARGA DE ARCHIVO EN GRAFO
W = leer_archivo(archivo_test)

dibujarGrafo(W, print_ejes=False)

# defino la probabilidad de salto de continuar los links de la pagina actual
p = 0.5
# Realizo el test unitario para el calculo del mayor score, que pruebe que el codigo funciona correctamente.
print('*'*50)
print('Test unitario 1')
try:
    assert(np.isclose(obtenerMaximoRankingScore(W, p), 0.1811, atol=0.0001))
except:
    print('OUCH!! - No paso el test unitario')
else:
    print('BIEN! - Paso correctamente el test unitario')
print('*'*50)
# Out:
# **************************************************
# Test unitario 1
# BIEN! - Paso correctamente el test unitario
# **************************************************

# %% [markdown]
# ### Test Unitarios Adicionales
#
# El grupo **deberá** proponer al menos 3 instancias de prueba no triviales, dos de las cuales deben ser de tipo TODOS LOS NODOS CONECTADOS, y otra de tipo NINGUNO CONECTADO. La tercera instancia queda a criterio del grupo.
#
# Para el análisis, guiarse y responder las siguientes preguntas:
#
# * ¿Cómo es el ranking obtenido en cada caso de acuerdo a la estructura del grafo páginas?
# * ¿Qué conclusiones pueden sacar de la interpretación de los resultados?
#
# Graficar los grafos usando las funciones en el **funciones.py**.

# %% [markdown]
# ### Analisis
#
# Para este analiis, decidimos implementar 3 grafos distintos:
# 1. Todas las paginas conectadas
# 2. Todas las paginas desconectadas
# 3. Una estructura semejante a un arbol binario
#
# Comencemos con el primer grafo:

# %%
import numpy
#ARCHIVOS DE ENTRADA
archivo_test = './tests/todos_conectados.txt'
    
#CARGA DE ARCHIVO EN GRAFO
W = leer_archivo(archivo_test)

dibujarGrafo(W, print_ejes=False)

# defino la probabilidad de salto de continuar los links de la pagina actual
p = 0.5
# Realizo el test unitario para el calculo del mayor score, que pruebe que el codigo funciona correctamente.
print('*'*50)
rnk, scr = calcularRanking(W,p)
print('Ranking:', rnk)
print('Score:', numpy.transpose(scr))
# Out:
# **************************************************
# Ranking: [1, 2, 6, 7, 8, 9, 3, 4, 5]
# Score: [[0.11111111 0.11111111 0.11111111 0.11111111 0.11111111 0.11111111
#   0.11111111 0.11111111 0.11111111]]

# %% [markdown]
# Podemos notar que al estar todos los nodos conectados entre sí, los scores son idénticos. Esto sucede porque: $$ \#links(\text{Páginas}[i]) = \#links(\text{Páginas}[j]) \quad \forall i, j \in \text{cantPáginas}(W) $$
#
# Luego, el orden de ranking de las paginas es indiferente ya que todos tienen el mismo score.
# Veamos ahora que sucece cuando estan todas desconectadas entre si:

# %%
import numpy
#ARCHIVOS DE ENTRADA
archivo_test = './tests/ninguno_conectado.txt'
    
#CARGA DE ARCHIVO EN GRAFO
W = leer_archivo(archivo_test)

dibujarGrafo(W, print_ejes=False)

# defino la probabilidad de salto de continuar los links de la pagina actual
p = 0.5
# Realizo el test unitario para el calculo del mayor score, que pruebe que el codigo funciona correctamente.
print('*'*50)
rnk, scr = calcularRanking(W,p)
print('Ranking:', rnk)
print('Score:', numpy.transpose(scr))
# Out:
# **************************************************
# Ranking: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Score: [[0.11111111 0.11111111 0.11111111 0.11111111 0.11111111 0.11111111
#   0.11111111 0.11111111 0.11111111]]

# %% [markdown]
# Notemos que sucede lo mismo que con el todos conectados, ya que en este caso todos los nodos tienen misma cantidad de links salientes (0 Links).
# Viendo tanto este grafico como el anterior, podemos concluir en que mientras todos los nodos tengan la misma cantidad de links salientes,
# siempre el score va a ser igual para todos por lo tanto generando un empate total en el ranking.
#
# Ahora vamos a ir a el test inventado por nosotros el cual tiene la estructura de un arbol binario:
#
# (Nota: la implementacion del codigo de abajo es necesaria ya que si usabamos el codigo dado por la catedra, no se visualizaba la estructura de arbol ya que se genera casi aleatoriamente la estructura)

# %%
import numpy
import networkx as nx
import matplotlib.pyplot as plt
import pydot 
import numpy as np
#ARCHIVOS DE ENTRADA
archivo_test = './tests/test_arbol.txt'
    
#CARGA DE ARCHIVO EN GRAFO
W = leer_archivo(archivo_test)

def dibujar_arbol(W, print_ejes=True):
    options = {
        'node_color': 'yellow',
        'node_size': 200,
        'width': 3,
        'with_labels': True
    }

    N = W.shape[0]
    G = nx.DiGraph()  # Utilizar un grafo dirigido

    # Agregar nodos al grafo
    G.add_nodes_from(range(1, N+1))

    # Agregar conexiones entre los nodos basados en la matriz de adyacencia
    for i in range(N):
        for j in range(N):
            if W[i][j] == 1:
                G.add_edge(j+1, i+1)  # Invertir la dirección del enlace

    # Generar un árbol dirigido BFS a partir del nodo raíz 1
    T = nx.bfs_tree(G, source=1)

    # Utilizar un layout más ordenado
    pos = {
        1: (0, 3),  # Nodo 1 arriba
        2: (-1, 2.5), 3: (1, 2.5),  # Nodos 2 y 3 un nivel abajo
        4: (-1.5, 2), 5: (-0.5, 2), 6: (0.5, 2), 7: (1.5, 2),  # Nodos 4, 5, 6 y 7 un nivel más abajo
        8: (-1.75, 1.5), 9: (-1.25, 1.5), 10: (-0.75, 1.5), 11: (-0.25, 1.5), 12: (0.25, 1.5), 13: (0.75, 1.5), 14: (1.25, 1.5), 15: (1.75, 1.5)  # Nodos 8 al 15 en el fondo
    }

    # Dibujar el árbol
    if print_ejes:
        print('Ejes: ', [e for e in T.edges])

    nx.draw(T, pos, **options)
    plt.show()

dibujar_arbol(W, False)

# defino la probabilidad de salto de continuar los links de la pagina actual
p = 0.5
# Realizo el test unitario para el calculo del mayor score, que pruebe que el codigo funciona correctamente.
print('*'*50)
rnk, scr = calcularRanking(W,p)
print('Ranking:', rnk)
print('Score:', numpy.transpose(scr))
# Out:
# **************************************************
# Ranking: [8, 9, 10, 11, 12, 13, 14, 15, 4, 5, 6, 7, 2, 3, 1]
# Score: [[0.0516129  0.06451613 0.06451613 0.06774194 0.06774194 0.06774194
#   0.06774194 0.06854839 0.06854839 0.06854839 0.06854839 0.06854839
#   0.06854839 0.06854839 0.06854839]]

# %% [markdown]
# Podemos ver como a medida que nos desplazamos por los niveles de este arbol los score aumentan cada vez mas, es decir: $$ scr(nvl 1) < scr(nvl 2) < ... < scr(nvl Log_2(n)) < scr(nvl \ Log_2 (n + 1)) \implies max(score) = scr(nvl \ Log_2(n + 1)) $$
# Por lo tanto, las paginas mejor rankeadas son las del ultimo nivel del arbol. Esto se debe a que las paginas de los primero niveles apuntan hacia los ultimos niveles, generando una acumulacion de links y dandole mas importancia a las ultimas paginas. Pero, por ejemplo, si el arbol no estuviera balanceado, es decir, si quitaramos por ejemplo las paginas 9 y 12, no valdria decir que todas las paginas del ultimo nivel tienen el mismo puntaje. Asi que lo anterior se podria profundizar mas con otro ejemplo con mas nodos.
#
# En conclusion, esta estructura de grafo parece interesante para una posible extension del TP, asi como estaria bueno ver que sucede con sistemas con estructura de arbol de distinto orden.

# %% [markdown]
# ## Enunciado
#
# Sobre los casos de test que se encuentran en el folder `tests`, se pide realizar los análisis siguientes para todos los grafos del folder.

# %% [markdown]
# ### Análisis Cuantitativo
#
# Para el análisis cuantitativo, se pide, como mínimo, estudiar los tiempos de procesamiento en función del tamaño del grafo de páginas y de la densidad del mismo. Para esto, se espera que presenten gráficos mostrando los tiempos de ejecución para obtener la solución en función de la cantidad de nodos/links de diferentes grafos de páginas aleatorios.

# %%
def tiempoEjecucion(W, p): 
    """Calcula el tiempo de ejecucion de obtenerMaximoRankingScore en segundos

    Args:
        W: matriz de conectividad
        p: parametro del navegante aleatorio

    Returns:
        tiempo_ejecucion
    """    # calcula el tiempo de ejecucion de obtenerMaximoRankingScore 
    inicio = time.time() # inicia cronometro
    obtenerMaximoRankingScore(W, p)
    fin = time.time() # termina cronometro
    tiempo_ejecucion = fin - inicio 
    
    return tiempo_ejecucion

def tiempoEjecucionSize (dimension,p): 
    """Calcula el tiempo de ejecucion en base a la dimension de W

    Args:
        dimension: dimensión de W
        p: parametro del navegante aleatorio

    Returns:
        lista_tiempo: lista con los tiempos de ejecucion
        lista_size: lista de dimensiones paralelo a los tiempos de ejecucion
    """    
    i=2 # hago que sea minimo 2x2
    lista_tiempo=[]
    lista_size=[]
    while i <= dimension:
        W= np.random.choice([0, 1], size=(i,i)) # creo W con dim(i,i) con links random
        np.fill_diagonal(W, 0)
        tiempo_ejecucion= tiempoEjecucion(W, p)
        lista_tiempo.append(tiempo_ejecucion)
        lista_size.append(i)
        i+=1

    return lista_tiempo, lista_size

def tiempoEjecucionDensidad (densidad_maxima,p,size):
    """Calcula el tiempo de ejecucion en base a la densidad de W (densidad = links/nodos.)

    Args:
        densidad_maxima: densidad máxima de W que se grafica
        p: parametro del navegante aleatorio
        size: dimension de W (matriz cuadrada size x size)

    Returns:
        lista_tiempo: lista con los tiempos de ejecucion
        lista_densidad: lista de densidades paralelo a los tiempos de ejecucion
    """    
    lista_tiempo = []
    lista_densidad = []

    for n in range(50, densidad_maxima * 50+1,50): # se elige 50 porque es un valor suficientemente alto para ver datos pero suficientemente bajo como para no romper la compu. igual cumple por lo explicado en notas. el valor de 50 es indifirente.
        W = np.zeros((size, size), dtype=int)
        np.fill_diagonal(W, 0)
        indices = np.random.choice(size * size, n, replace=False) 
        indices = np.unravel_index(indices, W.shape) # This line converts a flat index or array of flat indices into a tuple of coordinate arrays. Since we're dealing with a 2D array W, we use W.shape to specify its shape. This function essentially converts the flat indices obtained in the previous step into 2D indices that correspond to the positions in the original array W. magia de numpy 
        W[indices] = 1
        tiempo_ejecucion= tiempoEjecucion(W, p)
        lista_tiempo.append(tiempo_ejecucion)
        lista_densidad.append(n/50)
    
    return lista_tiempo, lista_densidad
    

def regresionLin(x, y):
    # esta es una funcion auxiliar, creemos innecesario hacerle un docstring pues simplemente calcula la
    # regresion lineal dado un set de datos.
    slope, intercept, r, p, std_err = stats.linregress(x, y)   
    return np.multiply(slope, x) + intercept # es necesario pues float * lista se arregla con np.multiply :D

# %%
def graficarDensidadRegresion(): # grafica el tiempo de ejecucion en funcion de la densidad de W
    sns.set_style("darkgrid")
    for i in range(10):
        tiempo, densidad = tiempoEjecucionDensidad (50,0.5,50+i*10)
        plt.scatter(densidad,tiempo,s=8, label=f'{50+i*10}x{50+i*10}')
        regresion_lineal = regresionLin(densidad, tiempo)
        plt.plot(densidad, regresion_lineal)

    plt.xlabel('Densidad de W (cantidad de links/cantidad de nodos)')
    plt.ylabel('Tiempo de Ejecucion (s)')
    plt.title('Tiempo de Ejecucion en funcion a la Densidad de W')
    plt.legend(fontsize='10')
    plt.grid(True)
    plt.show()   

graficarDensidadRegresion()

# %% [markdown]
# Observar que las lineas de regresion son constantes, o sea, en este caso la fuerza de regresion es nula. Esto es debido a que lo que realmente afecta al tiempo de ejecucion no es la densidad, sino la dimension. La complejidad algoritmica de procesar la matriz esta dada por la cantidad de ejecuciones que tiene que procesar mi algoritmo, no si en las posiciones hay 1 o 0. En este caso la complejidad es de $O(n^2)$, pues tenemos una matriz cuadrada. Veamos el tiempo de ejecucion en funcion al tamaño de W a continuacion:

# %%
def graficarDimension(valor_p):    
    for i in range(5):
        lista_tiempo, lista_size = tiempoEjecucionSize(100, valor_p)

    sns.set_style("darkgrid")
    plt.scatter(lista_size,lista_tiempo, color='seagreen', label=f'p={valor_p}', marker='o')
    plt.plot(lista_size,lista_tiempo, color='darkgreen', linestyle='-')
    plt.xlabel('Dimensiones de W')
    plt.ylabel('Tiempo de Ejecucion (s)')
    plt.title('Tiempo de ejecucion segun la Dimension de W')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# p = 0.25
graficarDimension(0.25)

# %%
# p = 0.5
graficarDimension(0.5)

# %%
# p = 0.75
graficarDimension(0.75)

# %% [markdown]
# *En efecto, lo que importa es el tamaño.* La curva tiene una clara tendencia polinomial, que en este caso va acorde a lo dicho anteriormente: como estamos trabajando con matrices de tamaño $n $ x $ n$, la cantidad de operacion es de $n^2$. Hay una clara correlacion entre el tiempo de ejecucion y la complejidad algoritmica.
# Notar que en los tres graficos, se puede ver un salto anormal en el tiempo de ejecucion en la dimension ~65, ya que pasa de aproximadamente 0.01s a casi 0.04s en los tres.
#
# Veamos si hay errores significativos en el calculo del ranking para concluir si realmente vale lo dicho anteriormente o no, usando p = 0.5 como se indico en los lineamientos:

# %%
def graficarDimensionPlotError():
    promedios_tiempo = []
    errores_tiempo = []
    densidades = []

    for i in range(10):
        tiempo, densidad = tiempoEjecucionDensidad(50, 0.5, 50+i*10)
        promedios_tiempo.append(np.mean(tiempo))
        errores_tiempo.append(np.std(tiempo))
        densidades.append(50+i*10)

    sns.set_style("darkgrid")
    plt.errorbar(densidades, promedios_tiempo, yerr=errores_tiempo, fmt='o-', capsize=5)
    plt.xlabel('Dimension')
    plt.ylabel('Tiempo de ejecucion (s)')
    plt.title('Tiempo en Ejecucion en función de la Dimension con desviacion estandar')
    plt.grid(True)
    plt.show()

graficarDimensionPlotError()

# %% [markdown]
# Como podemos ver, el grafico es acorde a los anteriores, en las dimensiones menores a 65 no hay una gran desviacion en los tiempos de ejecucion, mientras en que pasada la dimension 65 la desviacion es mayor, como se puede observar en los graficos anteriores.
#
# En conclusion, la *dimension* influye directamente en el tiempo de ejecucion mientras que la *densidad* no influye en absolutamente nada del tiempo de ejecucion.

# %% [markdown]
# ### Análisis Cualitativo
#
# Para el análisis cualitativo se deberán estudiar los rankings obtenidos, en función de la estructura del grafo, y del valor de $p$. Para esto, se espera que presenten gráficos mostrando las probabilidades de las páginas mejor rankeadas en función del valor de $p$.

# %% [markdown]
# Para el analisis cualitativo, decidimos graficar los valores de los puntajes de cada pagina tomando al valor de p como variable independiente. Decidimos ver varios casos de tests que nos parecieron interesantes de ver.

# %%
def calculoProbabilidadesScore(W,subdivisiones_p):
    # la necesidad de crear subdivisiones distintas en linspace es por el rendimiento de la 
    # maquina, no tenemos un i9 de 13va generacion. se detalla mejor en los bloques de texto
    valores_p = np.linspace(0.02, 0.99, subdivisiones_p) # nos es util para 15 y 30 segs
    rnk0, scr0 = calcularRanking(W, 0.01)
    matriz_scr_p = np.array(scr0).reshape(-1, 1) 
    for p in valores_p:
        ranking, scr = calcularRanking(W, p)
        scr_columna = np.array(scr).reshape(-1, 1)
        matriz_scr_p = np.hstack((matriz_scr_p, scr_columna)) # abracadabra
    return matriz_scr_p[:, 1:], valores_p 
    # Cambié matriz_scr_p[i] a matriz_scr_p[:, i] para seleccionar correctamente cada columna de matriz_scr_p.
    # Esto asegura que cada fila de matriz_scr_p tenga el mismo tamaño que valores_p. Atte. GPT

# %%
def graficarProbabilidadesScore(subdiv):
    """
    Crea un gráfico de linea para visualizar la relación entre
    el valor de p y las probabilidades de las páginas.
    """
    W = leer_archivo(archivo_test)
    npages = W.shape[0]
    matriz_scr_p, valores_p = calculoProbabilidadesScore(W,subdiv)
    
    # Crear el gráfico de dispersión con líneas de contornoi
    sns.set_style(style="darkgrid") # fashion fashion baby
    plt.figure(figsize=(8, 6)) # tamaño
    for i in range(npages):
        plt.plot(valores_p, matriz_scr_p[i])
    plt.xlabel('Valor de p')
    plt.ylabel('Puntaje de pagina')
    plt.title('Puntaje en funcion de parametro p')
    plt.show()

# %% [markdown]
# Primero, veamos el caso del test dos estrellas:

# %%
archivo_test='./tests/test_dosestrellas.txt'
graficarProbabilidadesScore(99)

# %% [markdown]
# Se ven 3 lineas distinguidas, donde pareceria que no salen del mismo punto, pero en realidad, estos se debe a que usamos 0.01 como valor minimo de p. Como el intervalo abierto tiene infimo (0) pero no minimo, podemos proponer usar el minimo computacional o algo que se acerque mucho a eso. Por ejemplo, si usamos p = $1 * 10^{-9}$, vemos que la matriz de puntajes es
# $$scr = \begin{pmatrix}
# 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \\\ 0.08333333
# \end{pmatrix}$$
#
# lo cual indica que $ \lim_{p\to 0} = 0.8\hat3 = 1/12 $. Esto se debe a que el navegante aleatorio posee control total de los saltos en las paginas; entonces, al ser casi 100% la probabilidad de salto, que hayan o no links entre las paginas da igual, ya que como vimos en el caso "*ninguno_conectado*", los puntajes de todas las paginas son iguales, y es igual a 1 sobre la cantidad de paginas total.
#
# Pero, ¿por que unicamente vemos tres lineas? Esto se debe a que hay varias paginas que empatan en cuanto a puntaje. Veamos cuanto da la matriz de puntajes cuando p = 0.5:
# $$scr = \begin{pmatrix}
# 0.07971014\\\
# 0.05978261\\\
# 0.05978261\\\
# 0.05978261\\\
# 0.05978261\\\
# 0.18115942\\\
# 0.18115942\\\
# 0.07971014\\\
# 0.05978261\\\
# 0.05978261\\\
# 0.05978261\\\
# 0.05978261
# \end{pmatrix}$$
#
# Se notan que hay 3 valores unicos, $ 0.07971014, 0.05978261$ y $0.18115942 $. O sea, que en realidad son 12 lineas superpuestas en 3 grupos. Ademas vemos que convergen exactamente a los mismos puntos en sus determinados grupos.
#
# Veamos ahora, el caso del test de 15 segundos, que llevo 15 *minutos* en graficar lo siguiente:

# %%
archivo_test='./tests/test_15_segundos.txt'
graficarProbabilidadesScore(6)

# %% [markdown]
# De la misma manera, podemos ver que los datos vuelven a salir de un punto y luego convergen a sus respectivos valores. Veamos la matriz de puntajes cuando $p\to0$:
# $$scr = \begin{pmatrix}
# 0.0005
# \\\ 0.0005
# \\\ 0.0005
# \\\ .
# \\\ .
# \\\ .
# \\\ 0.0005
# \\\ 0.0005
# \\\ 0.0005
# \end{pmatrix}$$
# lo cual es correcto ya que en el grafico se ve que salen de $0.0005$ todos los valores. De nuevo, este valor es 1 sobre la cantidad de paginas, o sea $1/1500$. Aun asi, el grafico no esta muy claro; asi que analizemos unicamente las paginas mejores rankeadas. Veamos como nos queda la matriz de rankings y sus respectivos puntajes:
# $$
# rnk = \begin{pmatrix}
# 990
# \\\ 1404
# \\\ 1689
# \\\ 341
# \\\ 448
# \\\ ...
# \end{pmatrix}
# \hspace{3cm}
# scr = \begin{pmatrix}
# 0.00222961
# \\\ 0.00193562
# \\\ 0.00180574
# \\\ 0.00174801
# \\\ 0.00170606
# \end{pmatrix}
# $$
# En efecto, las mejores paginas son las que se muestran en la matriz, ya que se pueden distinguir individualmente estas paginas en el grafico anterior. Aun asi, grafiquemos solo estas paginas.
# Definamos una funcion auxiliar para poder elegir que paginas graficar:

# %%
def graficarProbabilidadesScoreFiltrado(subdiv):
    """
    Crea un gráfico de línea para visualizar la relación entre
    el valor de p y las probabilidades de las páginas mejor rankeadas.
    """
    W = leer_archivo(archivo_test)
    matriz_scr_p, valores_p = calculoProbabilidadesScore(W, subdiv)
    rnk, scr = calcularRanking(W, valores_p[-1])
    top_5_indices = rnk[:5] # toma los primeros 5 indices
    
    sns.set_style(style="darkgrid")  # fashion fashion baby
    plt.figure(figsize=(8, 6))  # tamaño
    for i in top_5_indices:
        plt.plot(valores_p, matriz_scr_p[i-1], label=f'Página {i}')
    
    plt.xlabel('Valor de p')
    plt.ylabel('Puntaje de página')
    plt.title('Puntaje en función de parámetro p')
    plt.legend()
    plt.show()

# %%
archivo_test = './tests/test_15_segundos.txt'
graficarProbabilidadesScoreFiltrado(6)

# %% [markdown]
# Como podemos ver, cumple con todo lo que dijimos anteriormente. En este grafico se ven mejor las mejores paginas.
#
# Grafiquemos el siguiente test, *test_30_segundos*:

# %%
archivo_test='./tests/test_30_segundos.txt'
graficarProbabilidadesScore(3)

# %% [markdown]
# Hermoso grafico, es interesante ver como sucede lo mismo nuevamente. El analisis seria practicamente el mismo que los anteriores casos, podemos ver como hay paginas aisladas que reciben mejor score que las otras a medida que $p \to1 $.  Usando la funcion *calcularRanking* obtenemos que las paginas mejor puntuadas y sus respectivos puntajes son:
#
# $$
# rnk = \begin{pmatrix}
# 2883
# \\\ 879
# \\\ 446
# \\\ 733
# \\\ 2274
# \\\ ...
# \end{pmatrix}
# \hspace{3cm}
# scr = \begin{pmatrix}
# 0.00122886
# \\\ 0.00108944
# \\\ 0.00105831
# \\\ 0.00104564
# \\\ 0.00103628
# \end{pmatrix}
# $$
#
# Veamos si podemos graficar los puntajes de estas paginas individualmente:

# %%
archivo_test = './tests/test_30_segundos.txt'
graficarProbabilidadesScoreFiltrado(3)

# %% [markdown]
# En este grafico se pueden observar mejor las paginas mejor rankeadas, y sus respectivos valores.

# %% [markdown]
# ### Dos estrellas
#
# Para el caso **test_dosestrellas.txt** se pregunta:
#
# ¿Cuál es la mínima cantidad de links que se deben agregar para que la pagina correspondiente al nodo 1 quede primera en el ranking? ¿ Cómo se modificó la conectividad? Analizar.

# %% [markdown]
# Notemos que la pagina correspondiente al nodo 1 es la 3era pagina en el orden del ranking. Por delante de la misma se encuentran las paginas correspondientes a los nodos 6 y 7 que se encuentran empatados con un scr de aproximadamente 0.181.
#
# Observando el ranking que nos da el test dos estrellas:
# $$
# \begin{pmatrix}
# 6
# \\\ 7
# \\\ 1 \\\ 8 \\\ 2 \\\ 3 \\\ 4 \\\ 5 \\\ 9 \\\ 10 \\\ 11 \\\ 12
# \end{pmatrix}
# $$
# llegamos a la conclusion que los puntajes mas altos son los de las paginas 6 y 7 empatados con aproximadamente $0.181$, Luego los siguen las paginas 1 y 8 con aproximadamente $0.079$ y por ultimo quedan
# las paginas 2, 3, 4, 5, 9, 10, 11, 12 empatadas todas con aprox $0.059$.
#
#
# A simple vista tenemos dos opciones para que solo agregando links la pagina correspondiente al nodo 1 quede primera en el ranking de:
#
# Opcion 1: Hacer a las paginas 6 y 7 menos importantes bajando asi su scoring y quedando la 1 por encima de ellas.
#           Para generar esto deberiamos agregar varios links salientes de las paginas 6 y 7 para que estas bajen su importancia.
#
# Opcion 2: Aumentar la importancia de la pagina 1 de forma tal que sobrepase a las paginas 6 y 7.
#           Para generar esto deberiamos agregar varios links entrantes a la pagina 1.
#
# Veamos primero la opcion 1:

# %%
import numpy
#ARCHIVOS DE ENTRADA
archivo_test = './tests/test_dosestrellas_op1.txt'
    
#CARGA DE ARCHIVO EN GRAFO
W = leer_archivo(archivo_test)

dibujarGrafo(W, print_ejes=False)

# defino la probabilidad de salto de continuar los links de la pagina actual
p = 0.5
# Realizo el test unitario para el calculo del mayor score, que pruebe que el codigo funciona correctamente.
print('*'*50)
rnk, scr = calcularRanking(W,p)
print('Ranking:', rnk)
print('Score:', numpy.transpose(scr))
# Out:
# **************************************************
# Ranking: [6, 7, 1, 8, 2, 3, 4, 5, 9, 10, 11, 12]
# Score: [[0.08785214 0.0699601  0.0699601  0.0699601  0.0699601  0.20354991
#   0.15876893 0.07156815 0.04960511 0.04960511 0.04960511 0.04960511]]

# %% [markdown]
# En este archivo de test agregamos 5 links salientes a la pagina 7, teniendo asi esta links hacia todas las paginas. Podemos notar que el score de esta pagina bajo a 0.15 por lo que no es suficiente para hacer que el score sea mas bajo que el de la pagina corresponiente al nodo 1, por lo que esta opcion no es factible.
#
# Veamos la opcion 2:

# %%
import numpy
#ARCHIVOS DE ENTRADA
archivo_test = './tests/test_dosestrellas_op2.txt'
    
#CARGA DE ARCHIVO EN GRAFO
W = leer_archivo(archivo_test)

dibujarGrafo(W, print_ejes=False)

# defino la probabilidad de salto de continuar los links de la pagina actual
p = 0.5
# Realizo el test unitario para el calculo del mayor score, que pruebe que el codigo funciona correctamente.
print('*'*50)
rnk, scr = calcularRanking(W,p)
print('Ranking:', rnk)
print('Score:', numpy.transpose(scr))
# Out:
# **************************************************
# Ranking: [1, 6, 7, 8, 9, 10, 11, 2, 3, 4, 5, 12]
# Score: [[0.15120275 0.05670103 0.05670103 0.05670103 0.05670103 0.15034364
#   0.15034364 0.09450172 0.05670103 0.05670103 0.05670103 0.05670103]]

# %% [markdown]
# En este test buscamos agregarle links a la pagina 1 para aumentar su importancia. A su vez buscamos agregar links salientes a las paginas que envian links tambien hacia las paginas 6 y 7 de forma tal que la importancia de estas paginas sea menor para que el score de 6 y 7 se vea disminuido. Veamoslo explicito con el ejemplo:
#
# Agregamos los siguientes links:
# - 9 $\to$ 1
# - 10 $\to$ 1
# - 4 $\to$ 1
# - 3  $\to$ 1
# - 2 $\to$1
#
# Notemos que añadimos un link del 7 al 1, ya que al 7 ser la pagina de mayor importancia es un strong link hacia nuestra pagina 1.
# Luego agregamos los links del 9 y 10, de esta forma aumentamos aun mas la importancia de la pagina 1 y por lo contrario la importancaia de las paginas 9 y 10 se ve disminuida por ende la del 7 tambien ya que estos tenian un puntero hacia la misma.
# Por ultimo hicimos lo mismo que con el caso del 4, 3 y 2 ya que estos bajan la importancia del 6 pues constituyen los punteros hacia el mismo.
#
# Podemos observar que en el caso de la estrella del 6 hubo que agregar un link mas, esto es debido a que el 1 tiene un puntero al 6 y el link del 1 es cada vez mas fuerte por lo que inevitablemente hay que debilitar mas a los demas links del 6.
